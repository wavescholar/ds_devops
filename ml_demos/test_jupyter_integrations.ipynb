# %%
# FOR KERAS UTILS PLOT
# !pip install -q pydot
# !pip install -q pydotplus
# !apt-get install -q graphviz
# !pip install -q git+https://github.com/qubvel/classification_models.git

import Levenshtein

# %%
import qgrid
import pandas as pd
df = pd.read_csv('')

# %%
# !conda list
# Out:
# # packages in environment at /home/bruce/anaconda3/envs/snowflakes:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                       1_gnu
# _tflow_select             2.3.0                       mkl
# absl-py                   0.13.0           py38h06a4308_0
# aiohttp                   3.7.4            py38h27cfd23_1
# aiohttp-cors              0.7.0                    pypi_0    pypi
# aioredis                  1.3.1                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# alembic                   1.7.1                    pypi_0    pypi
# altair                    4.1.0                    pypi_0    pypi
# anyconfig                 0.10.1                   pypi_0    pypi
# anyio                     3.3.1                    pypi_0    pypi
# appdirs                   1.4.4              pyhd3eb1b0_0
# argon2-cffi               21.1.0                   pypi_0    pypi
# arrow                     1.1.1                    pypi_0    pypi
# arrow-cpp                 4.0.1            py38hced866c_3
# arviz                     0.11.2             pyhd3eb1b0_0
# astor                     0.8.1            py38h06a4308_0
# astunparse                1.6.3                      py_0
# async-timeout             3.0.1            py38h06a4308_0
# async_generator           1.10               pyhd3eb1b0_0
# attrs                     21.2.0             pyhd3eb1b0_0
# autograd                  1.3                        py_0    conda-forge
# autopage                  0.4.0                    pypi_0    pypi
# aws-c-common              0.4.57               he6710b0_1
# aws-c-event-stream        0.1.6                h2531618_5
# aws-checksums             0.1.9                he6710b0_0
# aws-sdk-cpp               1.8.185              hce553d0_0
# babel                     2.9.1              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports-zoneinfo        0.2.1                    pypi_0    pypi
# base58                    2.1.0                    pypi_0    pypi
# binaryornot               0.4.4                    pypi_0    pypi
# binutils_impl_linux-64    2.33.1               he6710b0_7
# binutils_linux-64         2.33.1              h9595d00_15
# black                     19.10b0                    py_0
# blas                      1.0                    openblas
# bleach                    4.1.0                    pypi_0    pypi
# blessings                 1.7                      pypi_0    pypi
# blinker                   1.4              py38h06a4308_0
# boltons                   21.0.0                   pypi_0    pypi
# boost-cpp                 1.73.0              h27cfd23_11
# boto3                     1.18.21            pyhd3eb1b0_0
# botocore                  1.21.21            pyhd3eb1b0_1
# bottleneck                1.3.2            py38heb32a55_1
# brotli                    1.0.9                he6710b0_2
# brotlipy                  0.7.0           py38h27cfd23_1003
# bzip2                     1.0.8                h7b6447c_0
# c-ares                    1.17.1               h27cfd23_0
# ca-certificates           2021.7.5             h06a4308_1
# cachetools                4.2.2              pyhd3eb1b0_0
# catalogue                 1.0.0                    py38_1
# catboost                  0.26.1                   pypi_0    pypi
# category-encoders         2.2.2                    pypi_0    pypi
# certifi                   2021.5.30                pypi_0    pypi
# cffi                      1.14.6           py38h400218f_0
# cftime                    1.5.0            py38h6323ea4_0
# chardet                   3.0.4           py38h06a4308_1003
# charset-normalizer        2.0.4              pyhd3eb1b0_0
# clang                     5.0                      pypi_0    pypi
# click                     7.1.2                    pypi_0    pypi
# cliff                     3.9.0                    pypi_0    pypi
# cloudpickle               1.6.0              pyhd3eb1b0_0
# cmaes                     0.8.2                    pypi_0    pypi
# cmd2                      2.1.2                    pypi_0    pypi
# cmdstanpy                 0.9.68                   pypi_0    pypi
# colorama                  0.4.4                    pypi_0    pypi
# colorful                  0.5.4                    pypi_0    pypi
# colorlog                  6.4.1                    pypi_0    pypi
# commonmark                0.9.1                    pypi_0    pypi
# contextlib2               21.6.0                   pypi_0    pypi
# convertdate               2.3.2                    pypi_0    pypi
# cookiecutter              1.7.3                    pypi_0    pypi
# coverage                  5.5              py38h27cfd23_2
# cryptography              3.4.7            py38hd23ed53_0
# curl                      7.78.0               h1ccaba5_0
# custom-inherit            2.3.1                    pypi_0    pypi
# cvxopt                    1.2.0            py38h75fe3a5_0
# cycler                    0.10.0                   py38_0
# cymem                     2.0.5            py38h2531618_0
# cython                    0.29.23          py38h2531618_0
# cython-blis               0.7.4            py38h27cfd23_1
# daal4py                   2021.3.0         py38hae6d005_0
# dal                       2021.3.0           h06a4308_557
# dask                      2021.9.0                 pypi_0    pypi
# dbus                      1.13.18              hb2f20db_0
# debtcollector             2.3.0                    pypi_0    pypi
# debugpy                   1.4.1            py38h295c915_0
# decorator                 5.0.9              pyhd3eb1b0_0
# defusedxml                0.7.1              pyhd3eb1b0_0
# dill                      0.3.4              pyhd3eb1b0_0
# distributed               2021.9.0                 pypi_0    pypi
# dit                       1.2.3                    pypi_0    pypi
# dm-tree                   0.1.6                    pypi_0    pypi
# docutils                  0.17.1           py38h06a4308_1
# double-conversion         3.1.5                he6710b0_1
# dynaconf                  3.1.5                    pypi_0    pypi
# en-core-web-sm            2.3.1                    pypi_0    pypi
# entrypoints               0.3                      pypi_0    pypi
# ephem                     4.0.0.2                  pypi_0    pypi
# expat                     2.4.1                h2531618_2
# fftw                      3.3.9                h27cfd23_1
# filelock                  3.0.12                   pypi_0    pypi
# flake8                    3.9.2              pyhd3eb1b0_0
# flatbuffers               1.12                     pypi_0    pypi
# fontconfig                2.13.1               h6c09931_0
# fonttools                 4.25.0             pyhd3eb1b0_0
# freetype                  2.10.4               h5ab3b9f_0
# fsspec                    0.8.7                    pypi_0    pypi
# funcy                     1.16                     pypi_0    pypi
# future                    0.18.2                   py38_1
# gast                      0.4.0                    pypi_0    pypi
# gcc_impl_linux-64         7.3.0                habb00fd_1
# gcc_linux-64              7.3.0               h553295d_15
# gensim                    4.0.1            py38h2531618_0
# gflags                    2.2.2                he6710b0_0
# gitdb                     4.0.7                    pypi_0    pypi
# gitpython                 3.1.18                   pypi_0    pypi
# glib                      2.69.1               h5202010_0
# glog                      0.5.0                h2531618_0
# glpk                      4.65                 h3ceedfd_2
# gmp                       6.2.1                h2531618_2
# google-api-core           1.22.2                   py38_0
# google-auth               1.33.0             pyhd3eb1b0_0
# google-auth-oauthlib      0.4.4              pyhd3eb1b0_0
# google-cloud-core         1.7.1              pyhd3eb1b0_0
# google-cloud-storage      1.19.0                     py_0    conda-forge
# google-crc32c             1.1.2            py38h27cfd23_0
# google-pasta              0.2.0              pyhd3eb1b0_0
# google-resumable-media    1.3.1              pyhd3eb1b0_1
# googleapis-common-protos  1.52.0           py38h06a4308_0
# gpustat                   0.6.0                    pypi_0    pypi
# great-expectations        0.13.32                  pypi_0    pypi
# greenlet                  1.1.1            py38h295c915_0
# grpc-cpp                  1.26.0               hf8bcb03_0
# grpcio                    1.40.0                   pypi_0    pypi
# gsl                       2.4                  h14c3975_4
# gst-plugins-base          1.14.0               h8213a91_2
# gstreamer                 1.14.0               h28cd5cc_2
# gxx_impl_linux-64         7.3.0                hdf63c60_1
# gxx_linux-64              7.3.0               h553295d_15
# h5py                      3.1.0                    pypi_0    pypi
# hdf4                      4.2.13               h3ca952b_2
# hdf5                      1.10.6               hb1b8bf9_0
# heapdict                  1.0.1                    pypi_0    pypi
# hijri-converter           2.2.1                    pypi_0    pypi
# hiredis                   2.0.0                    pypi_0    pypi
# holidays                  0.11.2                   pypi_0    pypi
# icu                       58.2                 he6710b0_3
# idna                      3.2                pyhd3eb1b0_0
# image-classifiers         1.0.0                    pypi_0    pypi
# imagesize                 1.2.0              pyhd3eb1b0_0
# importlib-metadata        4.8.1                    pypi_0    pypi
# importlib-resources       5.2.2                    pypi_0    pypi
# importlib_metadata        3.10.0               hd3eb1b0_0
# iniconfig                 1.1.1                    pypi_0    pypi
# ipykernel                 6.3.1                    pypi_0    pypi
# ipython                   7.27.0                   pypi_0    pypi
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# ipywidgets                7.6.4                    pypi_0    pypi
# jax                       0.2.20                   pypi_0    pypi
# jaxlib                    0.1.67+cuda111           pypi_0    pypi
# jedi                      0.18.0           py38h06a4308_1
# jinja2                    3.0.1              pyhd3eb1b0_0
# jinja2-time               0.2.0                    pypi_0    pypi
# jmespath                  0.10.0             pyhd3eb1b0_0
# joblib                    1.0.1              pyhd3eb1b0_0
# jpeg                      9b                   h024ee3a_2
# json5                     0.9.6                    pypi_0    pypi
# jsonpatch                 1.32                     pypi_0    pypi
# jsonpointer               2.1                      pypi_0    pypi
# jsonschema                3.0.2                    py38_0
# jupyter                   1.0.0                    py38_7
# jupyter-client            6.1.12                   pypi_0    pypi
# jupyter-server            1.11.0                   pypi_0    pypi
# jupyter-tabnine           1.2.3                    pypi_0    pypi
# jupyter_client            7.0.1              pyhd3eb1b0_0
# jupyter_console           6.4.0              pyhd3eb1b0_0
# jupyter_contrib_core      0.3.3                      py_2    conda-forge
# jupyter_contrib_nbextensions 0.5.1              pyhd8ed1ab_2    conda-forge
# jupyter_core              4.7.1            py38h06a4308_0
# jupyter_highlight_selected_word 0.2.0           py38h578d9bd_1002    conda-forge
# jupyter_latex_envs        1.4.6           pyhd8ed1ab_1002    conda-forge
# jupyter_nbextensions_configurator 0.4.1            py38h578d9bd_2    conda-forge
# jupyterlab                3.1.12                   pypi_0    pypi
# jupyterlab-server         2.8.1                    pypi_0    pypi
# jupyterlab-widgets        1.0.1                    pypi_0    pypi
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_widgets        1.0.0              pyhd3eb1b0_1
# jupyterthemes             0.20.0                     py_1    conda-forge
# kedro                     0.17.4                   pypi_0    pypi
# keras                     2.6.0                    pypi_0    pypi
# keras-applications        1.0.8                    pypi_0    pypi
# keras-base                2.4.3              pyhd3eb1b0_0
# keras-preprocessing       1.1.2              pyhd3eb1b0_0
# kiwisolver                1.3.1            py38h2531618_0
# korean-lunar-calendar     0.2.1                    pypi_0    pypi
# krb5                      1.19.2               hac12032_0
# lapack                    3.9.0                    netlib    conda-forge
# lcms2                     2.12                 h3be6417_0
# ld_impl_linux-64          2.33.1               h53a641e_7
# lesscpy                   0.15.0             pyhd8ed1ab_0    conda-forge
# libblas                   3.9.0           1_h6e990d7_netlib    conda-forge
# libboost                  1.73.0              h3ff78a5_11
# libcrc32c                 1.1.1                he6710b0_2
# libcurl                   7.78.0               h0b77cf5_0
# libedit                   3.1.20210714         h7f8727e_0
# libev                     4.33                 h7b6447c_0
# libevent                  2.1.8                h1ba5d50_1
# libffi                    3.3                  he6710b0_2
# libgcc-ng                 9.3.0               h5101ec6_17
# libgfortran-ng            7.5.0               ha8ba4b0_17
# libgfortran4              7.5.0               ha8ba4b0_17
# libgomp                   9.3.0               h5101ec6_17
# liblapack                 3.9.0           3_h893e4fe_netlib    conda-forge
# libnetcdf                 4.6.1                h2053bdc_4
# libnghttp2                1.41.0               hf8bcb03_2
# libopenblas               0.3.13               h4367d64_0
# libpng                    1.6.37               hbc83047_0
# libprotobuf               3.11.2               hd408876_0
# libsodium                 1.0.18               h7b6447c_0
# libssh2                   1.9.0                h1ba5d50_1
# libstdcxx-ng              9.3.0               hd4cf53a_17
# libthrift                 0.13.0               hfb8234f_6
# libtiff                   4.2.0                h85742a9_0
# libuuid                   1.0.3                h1bed415_2
# libwebp-base              1.2.0                h27cfd23_0
# libxcb                    1.14                 h7b6447c_0
# libxml2                   2.9.12               h03d6c58_0
# libxslt                   1.1.34               hc22bd24_0
# lightgbm                  3.2.1                    pypi_0    pypi
# llvmlite                  0.37.0                   pypi_0    pypi
# locket                    0.2.1                    pypi_0    pypi
# lunarcalendar             0.0.9                    pypi_0    pypi
# lxml                      4.6.3            py38h9120a33_0
# lz4-c                     1.9.3                h295c915_1
# mako                      1.1.5                    pypi_0    pypi
# markdown                  3.3.4            py38h06a4308_0
# markupsafe                2.0.1            py38h27cfd23_0
# matplotlib                3.4.2            py38h06a4308_0
# matplotlib-base           3.4.2            py38hab158f2_0
# matplotlib-inline         0.1.3                    pypi_0    pypi
# matrixprofile             1.1.10                   pypi_0    pypi
# mccabe                    0.6.1                    py38_1
# metis                     5.1.0                hf484d3e_4
# midaspy                   1.2.1                    pypi_0    pypi
# missingno                 0.5.0                    pypi_0    pypi
# mistune                   0.8.4           py38h7b6447c_1000
# mpi                       1.0                       mpich
# mpich                     3.3.2                hc856adb_0
# msgpack                   1.0.2                    pypi_0    pypi
# multidict                 5.1.0            py38h27cfd23_2
# munkres                   1.1.4                      py_0
# murmurhash                1.0.5            py38h2531618_0
# mypy_extensions           0.4.3                    py38_0
# nbclassic                 0.3.2                    pypi_0    pypi
# nbclient                  0.5.4                    pypi_0    pypi
# nbconvert                 6.1.0            py38h06a4308_0
# nbformat                  5.1.3              pyhd3eb1b0_0
# ncurses                   6.2                  he6710b0_1
# nest-asyncio              1.5.1              pyhd3eb1b0_0
# netcdf4                   1.5.7            py38h0a24e14_0
# nltk                      3.6.2              pyhd3eb1b0_0
# notebook                  6.4.3            py38h06a4308_0
# numba                     0.54.0                   pypi_0    pypi
# numexpr                   2.7.3            py38h4be448d_1
# numpy                     1.19.5                   pypi_0    pypi
# numpy-base                1.20.3           py38h39b7dee_0
# nvidia-ml-py3             7.352.0                  pypi_0    pypi
# oauthlib                  3.1.1              pyhd3eb1b0_0
# olefile                   0.46               pyhd3eb1b0_0
# opencensus                0.7.13                   pypi_0    pypi
# opencensus-context        0.1.2                    pypi_0    pypi
# openjpeg                  2.4.0                h3ad879b_0
# openssl                   1.1.1l               h7f8727e_0
# opt_einsum                3.3.0              pyhd3eb1b0_1
# optuna                    2.9.1                    pypi_0    pypi
# orbit-ml                  1.0.17                   pypi_0    pypi
# orc                       1.6.7                h973521d_2
# osqp                      0.6.2.post0              pypi_0    pypi
# packaging                 21.0               pyhd3eb1b0_0
# pandas                    1.3.2                    pypi_0    pypi
# pandas-datareader         0.10.0             pyhd3eb1b0_0
# pandas-profiling          1.4.1                    py38_0
# pandasql                  0.7.3                    py38_1
# pandocfilters             1.4.3            py38h06a4308_1
# parso                     0.8.2              pyhd3eb1b0_0
# partd                     1.2.0                    pypi_0    pypi
# pathspec                  0.7.0                      py_0
# patsy                     0.5.1                    pypi_0    pypi
# pbr                       5.6.0                    pypi_0    pypi
# pcre                      8.45                 h295c915_0
# pexpect                   4.8.0              pyhd3eb1b0_3
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    8.3.1            py38h2c7a002_0
# pip                       21.0.1           py38h06a4308_0
# pip-tools                 5.5.0                    pypi_0    pypi
# plac                      1.1.0                    py38_1
# plotly                    5.3.1                    pypi_0    pypi
# pluggy                    0.13.1                   pypi_0    pypi
# ply                       3.11                       py_1    conda-forge
# pot                       0.7.0            py38h950e882_0    conda-forge
# powerline-gitstatus       1.3.1                    pypi_0    pypi
# poyo                      0.5.0                    pypi_0    pypi
# preshed                   3.0.5            py38h2531618_4
# prettytable               2.2.0                    pypi_0    pypi
# prometheus_client         0.11.0             pyhd3eb1b0_0
# prompt-toolkit            3.0.20                   pypi_0    pypi
# prompt_toolkit            3.0.17               hd3eb1b0_0
# prophet                   1.0.1                    pypi_0    pypi
# protobuf                  3.18.0                   pypi_0    pypi
# psutil                    5.8.0                    pypi_0    pypi
# ptyprocess                0.7.0              pyhd3eb1b0_2
# py                        1.10.0                   pypi_0    pypi
# py-spy                    0.3.8                    pypi_0    pypi
# py4j                      0.10.9.2           pyhd3eb1b0_0
# pyarrow                   5.0.0                    pypi_0    pypi
# pyasn1                    0.4.8              pyhd3eb1b0_0
# pyasn1-modules            0.2.8                      py_0
# pycodestyle               2.7.0              pyhd3eb1b0_0
# pycparser                 2.20                       py_2
# pydeck                    0.7.0                    pypi_0    pypi
# pydot                     1.4.2                    pypi_0    pypi
# pydotplus                 2.0.2                    pypi_0    pypi
# pyemd                     0.5.1            py38h9a67853_0
# pyflakes                  2.3.1              pyhd3eb1b0_0
# pygments                  2.10.0             pyhd3eb1b0_0
# pyjwt                     2.1.0            py38h06a4308_0
# pyldavis                  3.3.1                    pypi_0    pypi
# pymeeus                   0.5.11                   pypi_0    pypi
# pynndescent               0.5.4                    pypi_0    pypi
# pyopenssl                 20.0.1             pyhd3eb1b0_1
# pyparsing                 2.4.7              pyhd3eb1b0_0
# pyperclip                 1.8.2                    pypi_0    pypi
# pyqt                      5.9.2            py38h05f1152_4
# pyro-api                  0.1.2                    pypi_0    pypi
# pyro-ppl                  1.7.0                    pypi_0    pypi
# pyrsistent                0.18.0                   pypi_0    pypi
# pysocks                   1.7.1            py38h06a4308_0
# pyspark                   3.1.2              pyhd3eb1b0_0
# pystan                    2.19.1.1         py38ha9443f7_0
# pytest                    6.2.5                    pypi_0    pypi
# python                    3.8.11          h12debd9_0_cpython
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-graphviz           0.17                     pypi_0    pypi
# python-json-logger        2.0.2                    pypi_0    pypi
# python-slugify            5.0.2                    pypi_0    pypi
# python_abi                3.8                      2_cp38    conda-forge
# pytz                      2021.1             pyhd3eb1b0_0
# pyyaml                    5.4.1            py38h27cfd23_1
# pyzmq                     22.2.1           py38h295c915_1
# qdldl                     0.1.5.post0              pypi_0    pypi
# qgrid                     1.3.1                    pypi_0    pypi
# qt                        5.9.7                h5867ecd_1
# qtconsole                 5.1.0              pyhd3eb1b0_0
# qtpy                      1.10.0             pyhd3eb1b0_0
# ray                       1.6.0                    pypi_0    pypi
# re2                       2020.11.01           h2531618_1
# readline                  8.1                  h27cfd23_0
# redis                     3.5.3                    pypi_0    pypi
# regex                     2021.8.3         py38h7f8727e_0
# requests                  2.26.0             pyhd3eb1b0_0
# requests-oauthlib         1.3.0                      py_0
# requests-unixsocket       0.2.0                    pypi_0    pypi
# rich                      10.9.0                   pypi_0    pypi
# rsa                       4.7.2              pyhd3eb1b0_1
# ruamel-yaml               0.17.16                  pypi_0    pypi
# ruamel-yaml-clib          0.2.6                    pypi_0    pypi
# s3transfer                0.5.0              pyhd3eb1b0_0
# scikit-learn              0.24.2           py38ha9443f7_0
# scikit-learn-intelex      2021.3.0         py38h06a4308_0
# scipy                     1.7.1            py38hc65b3f8_2
# seaborn                   0.11.2                   pypi_0    pypi
# send2trash                1.8.0                    pypi_0    pypi
# setuptools                58.0.2                   pypi_0    pypi
# setuptools-git            1.2                      pypi_0    pypi
# sip                       4.19.13          py38he6710b0_0
# six                       1.15.0                   pypi_0    pypi
# sklearn                   0.0                      pypi_0    pypi
# smart_open                5.1.0              pyhd3eb1b0_0
# smmap                     4.0.0                    pypi_0    pypi
# snappy                    1.1.8                he6710b0_0
# sniffio                   1.2.0                    pypi_0    pypi
# snowballstemmer           2.1.0              pyhd3eb1b0_0
# sortedcontainers          2.4.0                    pypi_0    pypi
# spacy                     2.3.5            py38hff7bd54_0
# sphinx                    4.0.2              pyhd3eb1b0_0
# sphinxcontrib-applehelp   1.0.2              pyhd3eb1b0_0
# sphinxcontrib-devhelp     1.0.2              pyhd3eb1b0_0
# sphinxcontrib-htmlhelp    2.0.0              pyhd3eb1b0_0
# sphinxcontrib-jsmath      1.0.1              pyhd3eb1b0_0
# sphinxcontrib-qthelp      1.0.3              pyhd3eb1b0_0
# sphinxcontrib-serializinghtml 1.1.5              pyhd3eb1b0_0
# sqlalchemy                1.4.23                   pypi_0    pypi
# sqlite                    3.36.0               hc218d9a_0
# srsly                     1.0.5            py38h2531618_0
# statsmodels               0.12.2                   pypi_0    pypi
# stevedore                 3.4.0                    pypi_0    pypi
# streamlit                 0.88.0                   pypi_0    pypi
# stumpy                    1.9.2                    pypi_0    pypi
# suitesparse               5.2.0                h2ffa06c_0
# tbb                       2021.3.0             hd09550d_0
# tblib                     1.7.0                    pypi_0    pypi
# tenacity                  8.0.1                    pypi_0    pypi
# tensorboard               2.6.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.6.0                      py_0
# tensorflow                2.6.0                    pypi_0    pypi
# tensorflow-addons         0.14.0                   pypi_0    pypi
# tensorflow-base           2.3.0           mkl_py38hac35e67_0
# tensorflow-decision-forests 0.1.9                    pypi_0    pypi
# tensorflow-estimator      2.6.0                    pypi_0    pypi
# tensorflow-probability    0.13.0                   pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.12.1                   pypi_0    pypi
# testpath                  0.5.0              pyhd3eb1b0_0
# text-unidecode            1.3                      pypi_0    pypi
# thinc                     7.4.5            py38h9a67853_0
# threadpoolctl             2.2.0              pyh0d69192_0
# tk                        8.6.10               hbc83047_0
# toml                      0.10.2             pyhd3eb1b0_0
# toolz                     0.11.1                   pypi_0    pypi
# toposort                  1.6                      pypi_0    pypi
# torch                     1.9.0                    pypi_0    pypi
# tornado                   6.1              py38h27cfd23_0
# tqdm                      4.62.2                   pypi_0    pypi
# traitlets                 5.1.0                    pypi_0    pypi
# tsfresh                   0.18.0                   pypi_0    pypi
# typed-ast                 1.4.3            py38h7f8727e_1
# typeguard                 2.12.1                   pypi_0    pypi
# typing-extensions         3.7.4.3                  pypi_0    pypi
# typing_extensions         3.10.0.2           pyh06a4308_0
# tzlocal                   3.0                      pypi_0    pypi
# ujson                     4.1.0                    pypi_0    pypi
# umap-learn                0.5.1                    pypi_0    pypi
# uriparser                 0.9.3                he6710b0_1
# urllib3                   1.26.6             pyhd3eb1b0_1
# utf8proc                  2.6.1                h27cfd23_0
# validators                0.18.2                   pypi_0    pypi
# wasabi                    0.8.2              pyhd3eb1b0_0
# watchdog                  2.1.5                    pypi_0    pypi
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.2.1                    pypi_0    pypi
# werkzeug                  1.0.1              pyhd3eb1b0_0
# wheel                     0.37.0             pyhd3eb1b0_1
# widgetsnbextension        3.5.1                    py38_0
# wrapt                     1.12.1           py38h7b6447c_1
# wurlitzer                 2.1.1            py38h06a4308_0
# xarray                    0.19.0             pyhd3eb1b0_1
# xgboost                   1.4.2                    pypi_0    pypi
# xgboost-ray               0.1.2                    pypi_0    pypi
# xz                        5.2.5                h7b6447c_0
# yaml                      0.2.5                h7b6447c_0
# yarl                      1.6.3            py38h27cfd23_0
# zeromq                    4.3.4                h2531618_0
# zict                      2.0.0                    pypi_0    pypi
# zipp                      3.5.0              pyhd3eb1b0_0
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.4.9                haebb681_0

# %%
print("\n... IMPORTS STARTING ...\n")
print("\n\tVERSION INFORMATION")

# Machine Learning and Data Science Imports

# %%
# Machine Learning and Data Science Imports
import keras
import tensorflow as tf; print(f"\t\t– TENSORFLOW VERSION: {tf.__version__}");
import pandas as pd; pd.options.mode.chained_assignment = None;
import numpy as np; print(f"\t\t– NUMPY VERSION: {np.__version__}");
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      46 from tensorflow.python import distribute
# ---> 47 from tensorflow.python import keras
#      48 from tensorflow.python.feature_column import feature_column_lib as feature_column
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      26 from tensorflow.python.keras.engine import functional
# ---> 27 from tensorflow.python.keras.engine import sequential
#      28 from tensorflow.python.keras.engine import training
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in <module>
#      26 from tensorflow.python.framework import tensor_util
# ---> 27 from tensorflow.python.keras import layers as layer_module
#      28 from tensorflow.python.keras.engine import base_layer
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/layers/__init__.py in <module>
#     173 # Normalization layers.
# --> 174 from tensorflow.python.keras.layers.normalization import LayerNormalization
#     175 from tensorflow.python.keras.layers.normalization_v2 import SyncBatchNormalization
#
# ImportError: cannot import name 'LayerNormalization' from 'tensorflow.python.keras.layers.normalization' (/home/bruce/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/layers/normalization/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1777618/160839953.py in <module>
#       1 # Machine Learning and Data Science Imports
# ----> 2 import keras
#       3 import tensorflow as tf; print(f"\t\t– TENSORFLOW VERSION: {tf.__version__}");
#       4 import pandas as pd; pd.options.mode.chained_assignment = None;
#       5 import numpy as np; print(f"\t\t– NUMPY VERSION: {np.__version__}");
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %%
import keras
# Out:
# 2021-09-20 15:36:53.378622: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-09-20 15:36:53.378645: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/api/_v2/keras/__init__.py in <module>
#       9
# ---> 10 from keras import __version__
#      11 from keras.api._v2.keras import __internal__
#
# ImportError: cannot import name '__version__' from partially initialized module 'keras' (most likely due to a circular import) (/home/bruce/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1690673/3208813603.py in <module>
# ----> 1 import keras
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %%
import tensorflow_addons as tfa;
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/api/_v2/keras/__init__.py in <module>
#       9
# ---> 10 from keras import __version__
#      11 from keras.api._v2.keras import __internal__
#
# ImportError: cannot import name '__version__' from partially initialized module 'keras' (most likely due to a circular import) (/home/bruce/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1681500/3660227072.py in <module>
# ----> 1 import keras
#       2 import tensorflow_addons as tfa;
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/keras/__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %%
import pandas as pd; pd.options.mode.chained_assignment = None;
import numpy as np;

# %%
# Imports for Alternative Models
import classification_models
from classification_models.keras import Classifiers

# Built In Imports
from kaggle_datasets import KaggleDatasets
from collections import Counter
from datetime import datetime
from glob import glob
import warnings
import requests
import imageio
import IPython
import urllib
import zipfile
import pickle
import random
import shutil
import string
import math
import time
import gzip
import ast
import io
import os
import gc
import re

# Visualization Imports
from matplotlib.colors import ListedColormap
import matplotlib.patches as patches
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm; tqdm.pandas();
import plotly.express as px
import seaborn as sns
from PIL import Image
import matplotlib; print(f"\t\t– MATPLOTLIB VERSION: {matplotlib.__version__}");
import plotly
import PIL
import cv2


print("\n\n... IMPORTS COMPLETE ...\n")


gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "... Physical GPUs,", len(logical_gpus), "Logical GPUs ...\n")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# ... IMPORTS STARTING ...
#
#
# 	VERSION INFORMATION
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1588122/3413048778.py in <module>
#       3
#       4 # Machine Learning and Data Science Imports
# ----> 5 import tensorflow as tf; print(f"\t\t– TENSORFLOW VERSION: {tf.__version__}");
#       6 import tensorflow_addons as tfa; print(f"\t\t– TENSORFLOW ADDONS VERSION: {tfa.__version__}");
#       7 import pandas as pd; pd.options.mode.chained_assignment = None;
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      45 from tensorflow.python import data
#      46 from tensorflow.python import distribute
# ---> 47 from tensorflow.python import keras
#      48 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      49 from tensorflow.python.layers import layers
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      25
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#      29 from tensorflow.python.keras.engine.input_layer import Input
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      25 from tensorflow.python.keras import optimizers
#      26 from tensorflow.python.keras.engine import functional
# ---> 27 from tensorflow.python.keras.engine import sequential
#      28 from tensorflow.python.keras.engine import training
#      29 from tensorflow.python.keras.engine import training_v1
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in <module>
#      25 from tensorflow.python.framework import ops
#      26 from tensorflow.python.framework import tensor_util
# ---> 27 from tensorflow.python.keras import layers as layer_module
#      28 from tensorflow.python.keras.engine import base_layer
#      29 from tensorflow.python.keras.engine import functional
#
# ~/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/layers/__init__.py in <module>
#     172
#     173 # Normalization layers.
# --> 174 from tensorflow.python.keras.layers.normalization import LayerNormalization
#     175 from tensorflow.python.keras.layers.normalization_v2 import SyncBatchNormalization
#     176
#
# ImportError: cannot import name 'LayerNormalization' from 'tensorflow.python.keras.layers.normalization' (/home/bruce/anaconda3/envs/snowflakes/lib/python3.8/site-packages/tensorflow/python/keras/layers/normalization/__init__.py)
